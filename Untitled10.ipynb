# %% [markdown]
# <a href="https://colab.research.google.com/github/Gideono29/Machine-Learning-Projects/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Python Libraries

import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load dataset

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/breast-cancer-wisconsin.data"
names = ['id', 'clump_thickness', 'uniform_cell_size', 'uniform_cell_shape',
       'marginal_adhesion', 'single_epithelial_size', 'bare_nuclei',
       'bland_chromatin', 'normal_nucleoli', 'mitoses', 'class']
df = pd.read_csv(url, names=names)

# %%
df.head()
# Out:
#         id  clump_thickness  uniform_cell_size  uniform_cell_shape  \
# 0  1000025                5                  1                   1
# 1  1002945                5                  4                   4
# 2  1015425                3                  1                   1
# 3  1016277                6                  8                   8
# 4  1017023                4                  1                   1
#
#    marginal_adhesion  single_epithelial_size bare_nuclei  bland_chromatin  \
# 0                  1                       2           1                3
# 1                  5                       7          10                3
# 2                  1                       2           2                3
# 3                  1                       3           4                3
# 4                  3                       2           1                3
#
#    normal_nucleoli  mitoses  class
# 0                1        1      2
# 1                2        1      2
# ...

# %%
# Preprocess the data
df.replace('?', -99999, inplace=True)
print(df.axes)

df.drop(['id'], axis=1, inplace=True)
# Out:
# [RangeIndex(start=0, stop=699, step=1), Index(['id', 'clump_thickness', 'uniform_cell_size', 'uniform_cell_shape',
#        'marginal_adhesion', 'single_epithelial_size', 'bare_nuclei',
#        'bland_chromatin', 'normal_nucleoli', 'mitoses', 'class'],
#       dtype='object')]

# %%
#describe the dataset
print(df.describe())
# Out:
#        clump_thickness  uniform_cell_size  uniform_cell_shape  \
# count       699.000000         699.000000          699.000000
# mean          4.417740           3.134478            3.207439
# std           2.815741           3.051459            2.971913
# min           1.000000           1.000000            1.000000
# 25%           2.000000           1.000000            1.000000
# 50%           4.000000           1.000000            1.000000
# 75%           6.000000           5.000000            5.000000
# max          10.000000          10.000000           10.000000
#
#        marginal_adhesion  single_epithelial_size  bland_chromatin  \
# count         699.000000              699.000000       699.000000
# mean            2.806867                3.216023         3.437768
# std             2.855379                2.214300         2.438364
# min             1.000000                1.000000         1.000000
# 25%             1.000000                2.000000         2.000000
# ...

# %%
#plot histograms for each variable
df.hist (figsize = (10, 10))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# Assuming df is your preprocessed DataFrame (without 'id' column)

# Select features for the scatterplot matrix
features = ['clump_thickness', 'uniform_cell_size', 'uniform_cell_shape',
            'marginal_adhesion', 'single_epithelial_size', 'bare_nuclei',
            'bland_chromatin', 'normal_nucleoli', 'mitoses']

# Create the scatterplot matrix
scatter_matrix(df[features], figsize=(12, 12), diagonal='hist')
plt.show()

# %%
scatter_matrix(df, figsize=(20,20))
plt.show()

# %%
#Create X and Y database for training
X = np.array(df.drop(['class'], axis = 1))
y = np.array(df['class'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)  # Using random_state for reproducibility

# %%
# Testing Options
seed = 8
scoring = 'accuracy'

# %%
#Define models to train
models = []
models.append(('KNN', KNeighborsClassifier(n_neighbors = 5)))
models.append(('SVM', SVC()))

#evaluate both models
results = []
names = []
for name, model in models:
  model.fit(X_train, y_train)
  predictions = model.predict(X_test)
  print(name)
  print(accuracy_score(y_test, predictions))
# Out:
# KNN
# 0.9642857142857143
# SVM
# 0.6142857142857143

# %%
# Split data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)  # Using random_state for reproducibility

# Define models to train
models = []
models.append(('KNN', KNeighborsClassifier(n_neighbors=5)))
models.append(('SVM', SVC()))

# Evaluate each model
for name, model in models:
    model.fit(X_train, y_train)  # Train the model on the training data
    predictions = model.predict(X_val)  # Make predictions on the validation data

    # Print evaluation metrics
    print(f"Model: {name}")
    print(f"Accuracy: {accuracy_score(y_val, predictions)}")
    print(classification_report(y_val, predictions))
    print("-" * 30)
# Out:
# Model: KNN
# Accuracy: 0.9785714285714285
#               precision    recall  f1-score   support
#
#            2       0.99      0.98      0.98        93
#            4       0.96      0.98      0.97        47
#
#     accuracy                           0.98       140
#    macro avg       0.97      0.98      0.98       140
# weighted avg       0.98      0.98      0.98       140
#
# ------------------------------
# Model: SVM
# Accuracy: 0.6642857142857143
#               precision    recall  f1-score   support
#
#            2       0.66      1.00      0.80        93
#            4       0.00      0.00      0.00        47
#
#     accuracy                           0.66       140
#    macro avg       0.33      0.50      0.40       140
# weighted avg       0.44      0.66      0.53       140
#
# ------------------------------
# ...
